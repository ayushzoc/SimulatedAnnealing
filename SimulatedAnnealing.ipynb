# %% [markdown]
# #### Ashraya Joshi
# #### CSCI 692 - Randomized Algorithms
# #### Project 1 - Simulated Annealing

# %% [markdown]
# We are given a .png file that represents columns of a data. The objective is to find the optimal permutations of the image. The problem is closely related to the "Traveling Salesman Problem".

# %%
# Import the image using Image and ImageOps module from PIL package.
from PIL import Image, ImageOps
import numpy as np
from scipy import spatial
import cv2
import math
# Create an image object and convert to 8-bit grayscale image
img = Image.open("test.png").convert("L")
im_gray = cv2.imread("test.png", cv2.IMREAD_GRAYSCALE)
WIDTH, HEIGHT = img.size
CITY_COUNT = WIDTH
INITIAL_TEMPERATURE = 100000
STOPPING_TEMPERATURE = 1
TEMPERATURE_DECAY = 0.9995
img.size[0]
# Out:
# 1522

# %%
cities = np.array(img)
cities = cities.T
# print(np.linalg.norm(cities[:, 0] - cities[:, 1]))
# print(np.sqrt(np.sum(np.square(cities[:, 0] - cities[:, 1]))))

# %% [markdown]
# So, we have 1522 columns in the matrix, i.e. 1522 columns in the image. If we treat the problem as a TSP, we have 1522 cities. First, we will change every column of the matrix to their specific vectors.

# %%
def length(n1, n2):
    return np.sqrt(np.sum(np.square(cities[n1] - cities[n2])))

# %%
def total_length(cities, n):
    l = length(cities[0], cities[n-1])
    for i in range(n-1):
        l += length(cities[i], cities[i + 1])
    return l

# %%
def two_opt_optimization(sol_arr, t, n):
    ai = np.random.randint(0, n-1)
    bi = (ai + 1) % n
    ci = np.random.randint(0, n-1)
    di = (ci + 1) % n
    
    if ai != ci and bi != ci:
        a = sol_arr[ai]
        b = sol_arr[bi]
        c = sol_arr[ci]
        d = sol_arr[di]
        
        ab = length(a, b)
        cd = length(c, d)
        
        ac = length(a, c)
        bd = length(b, d)
        
        diff = (ab + cd) - (ac + bd)
        
        p = 0
        
        if diff < 0:
            p = math.exp(diff / t)
        elif diff > 0.05:
            p = 1
            
        if np.random.random() < p:
            new_arr = list(range(0, n))
            new_arr[0] = sol_arr[ai]
            i = 1
            
            while bi != ci:
                new_arr[i] = sol_arr[ci]
                i = i + 1
                ci = (ci - 1) % n
                
            new_arr[i] = sol_arr[bi]
            i = i + 1
            
            while ai != di:
                new_arr[i] = sol_arr[di]
                i = i + 1
                di = (di + 1) % n
                
            return new_arr
    return sol_arr

# %%
def sa_algorithm(cities):
    n = CITY_COUNT
    
    sol_arr = cities
    
    t = 100
    min_l = total_length(sol_arr, n)
    
    i = 0
    best_arr = []
    
    while t > 0.1:
        i = i + 1
        sol_arr = two_opt_optimization(sol_arr, t, n)
        
        if i >= 200:
            i = 0
            current_l = total_length(sol_arr, n)
            
            t = t * 0.9995
            
            if current_l < min_l:
                print(current_l)
                min_l = current_l
                best_arr = sol_arr[:]
    return best_arr

final_arr = sa_algorithm(cities)
final_l = total_length(final_arr, n)
# Out:
# 7719669.395254193
# 7485267.463031678
# 7289422.681408672
# 7099853.388917846
# 6929475.279296251
# 6774672.81804115
# 6655696.156918028
# 6479869.345264945
# 6373701.027568095
# 6264533.538285743
# 6130627.9888084335
# 6023657.6404277515
# 5914213.959866108
# 5852335.589380155
# 5742211.560590372
# 2169191.810057626
# 2166981.2249889635
# 2164746.35493684
# 2163441.0241341204
# 2162704.0880367607
# 2161187.605826939
# 2160063.507266608
# 2159953.812259348
# 2159947.82658962
# 2159071.684327708
# 2158850.786555612
# 2156755.7638212927
# 2156448.2419856405
# 2156286.730042125
# 2155859.748385116
# 2154871.2480460345
# 2154136.6881873747
# 2152614.70217237
# 2151397.216208558
# 2151057.5755195008
# 2150920.6347740386
# 2150575.7168374746
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\RAYJOS~1\AppData\Local\Temp/ipykernel_13340/3292659734.py in <module>
#      26     return best_arr
#      27
# ---> 28 final_arr = sa_algorithm(cities)
#      29 final_l = total_length(final_arr, n)
#
# C:\Users\RAYJOS~1\AppData\Local\Temp/ipykernel_13340/3292659734.py in sa_algorithm(cities)
#      16         if i >= 200:
#      17             i = 0
# ---> 18             current_l = total_length(sol_arr, n)
#      19
#      20             t = t * 0.9995
#
# C:\Users\RAYJOS~1\AppData\Local\Temp/ipykernel_13340/2347059833.py in total_length(cities, n)
#       2     l = length(cities[0], cities[n-1])
#       3     for i in range(n-1):
# ----> 4         l += length(cities[i], cities[i + 1])
#       5     return l
#
# C:\Users\RAYJOS~1\AppData\Local\Temp/ipykernel_13340/1422909263.py in length(n1, n2)
#       1 def length(n1, n2):
# ----> 2     return np.sqrt(np.sum(np.square(cities[n1] - cities[n2])))
#
# KeyboardInterrupt:

# %%
print(final_l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RAYJOS~1\AppData\Local\Temp/ipykernel_13340/3801272978.py in <module>
# ----> 1 print(final_l)
#
# NameError: name 'final_l' is not defined

# %%
def Initialize(count):
    solution = np.arange(count)
    np.random.shuffle(solution)
    return solution

# %%
def Evaluate(cities, solution):
    distance = 0
    for i in range(cities.shape[1]):
        index_a = solution[i]
        index_b = solution[i - 1]
        distance += np.sqrt(np.sum(np.square(cities[:, index_a] - cities[:, index_b])))
    return distance

# %%
def Modify(current):
    new = current.copy()
    index_a = np.random.randint(len(current))
    index_b = np.random.randint(len(current))
    while index_b == index_a:
        index_b = np.random.randint(len(current))
    new[index_a], new[index_b] = new[index_b], new[index_a]
    return new

# %%
current_solution = Initialize(CITY_COUNT)
print(current_solution)
current_score = Evaluate(cities, current_solution)
print(current_score)
best_score = worst_score = current_score
temperature = INITIAL_TEMPERATURE
while temperature > STOPPING_TEMPERATURE:
    new_solution = Modify(current_solution)
    new_score = Evaluate(cities, new_solution)
    best_score = min(best_score, new_score)
    worst_score = max(worst_score, new_score)
    if new_score < current_score:
        current_solution = new_solution
        current_score = new_score
    else:
        delta = abs(new_score - current_score)
        probability = np.exp(-delta / temperature)
        if probability > np.random.uniform():
            current_solution = new_solution
            current_score = new_score
    temperature *= TEMPERATURE_DECAY
# Out:
# [ 932 1239 1367 ... 1001 1090   89]
# 281087.01060841454

# %%
current_solution
# Out:
# array([ 962, 1307,  201, ...,  502,  327,  257])

# %%
final_matrix = []
for index in current_solution:
    final_matrix.append(cities[:, index])
final_matrix = np.vstack(final_matrix)
print(final_matrix.T.shape)
final_image = Image.fromarray(final_matrix.T, "L")
final_image.show()
# Out:
# (1395, 1522)
